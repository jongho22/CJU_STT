# %%
from whisper_jax import FlaxWhisperPipline
import jax.numpy as jnp
import whisper

# %%
from IPython.display import Audio
Audio('./광화문자생한방병원_1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pipeline = FlaxWhisperPipline("openai/whisper-medium", dtype=jnp.bfloat16, batch_size=16)

# %%
text = pipeline("./광화문자생한방병원_1.mp3", task="translate")
text['text']
# Out:
# ' If you are going to the hospital for breast disc surgery, please go to the exit 6 of Seodaemun Station.'

# %%
# from jax.lib import xla_bridge
# print(xla_bridge.get_backend().platform)

# model = whisper.load_model("medium")
# result = model.transcribe("광화문자생한방병원_1.mp3", fp16=False)
# result['text']

# %%
import torch
import whisper

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = whisper.load_model("medium")
model = model.to(device)

result = model.transcribe("광화문자생한방병원_1.mp3", fp16=False)
# Out:
# Using device: cuda

# %%
result['text']
# Out:
# ' 척추 디스크 비수술 치료 광화문 자생한방병원으로 가실 분은 서대문역 6번 출구로 나가시기 바랍니다.'
